# %%
#Importamos librerias
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns
pd.options.display.max_rows = 30
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
df = pd.read_csv('adult.csv')
df.shape
# Out:
# (32561, 15)

# %%
df = df.applymap(lambda x : np.nan if x == "?" else x).dropna()
df.shape
# Out:
# (30162, 15)

# %%
df["income2"] = df.income

# %%
#df.education.unique() # 16 valores distintos
#df.sort_values("education.num") # de 1 - preschool a 16 - Doctorate
#df.race.unique() # 5 val
#df.sex.unique() # 2 val
#df.occupation.unique() # 14 val

#df.fnlwgt.unique().shape
#sns.distplot(df.fnlwgt)

df["income2"] = np.where(df.income == '<=50K', 0, 1)
df
#df.income.unique()
#df['income']=df['income'].map({'<=50K': 0, '>50K': 1, '<=50K.': 0, '>50K.': 1})
#a_dummies = ["income"]
#columnas_dummies = ["income"]
#df_dummies = pd.get_dummies(df,a_dummies,columns=columnas_dummies)
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 1       82           Private  132870       HS-grad              9
# 3       54           Private  140359       7th-8th              4
# 4       41           Private  264663  Some-college             10
# 5       34           Private  216864       HS-grad              9
# 6       38           Private  150601          10th              6
# 7       74         State-gov   88638     Doctorate             16
# 8       68       Federal-gov  422013       HS-grad              9
# 10      45           Private  172274     Doctorate             16
# 11      38  Self-emp-not-inc  164526   Prof-school             15
# 12      52           Private  129177     Bachelors             13
# 13      32           Private  136204       Masters             14
# 15      46           Private   45363   Prof-school             15
# 16      45           Private  172822          11th              7
# ...

# %%
df.sort_values("race")
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 22499   47           Private  157901          11th              7
# 31500   31       Federal-gov   59732       HS-grad              9
# 24040   43         Local-gov  216070       Masters             14
# 10888   40           Private  310101  Some-college             10
# 2938    39           Private  106183       HS-grad              9
# 21216   80         Local-gov   20101       HS-grad              9
# 6339    31           Private  100997  Some-college             10
# 29387   46           Private  176552          11th              7
# 4679    25           Private  267044  Some-college             10
# 2932    25           Private  194897       HS-grad              9
# 6374    52  Self-emp-not-inc  242341       7th-8th              4
# 405     40  Self-emp-not-inc  284706   Prof-school             15
# 24079   27           Private  221252       HS-grad              9
# ...

# %%
sns.heatmap(df_dummies.corr());
