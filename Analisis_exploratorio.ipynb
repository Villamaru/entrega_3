# %% [markdown]
# Importamos librerias.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns
pd.options.display.max_rows = 30
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %% [markdown]
# Cargamos el dataset.

# %%
df = pd.read_csv('adult.csv')
df.shape
# Out:
# (32561, 15)

# %%
df = df.applymap(lambda x : np.nan if x == "?" else x).dropna()
df.shape
# Out:
# (30162, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
#print(df.workclass.unique()) 
#['Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc' 'Self-emp-inc','Local-gov' 'Without-pay']

#df.education.unique() 
# ['HS-grad', '7th-8th', 'Some-college', '10th', 'Doctorate','Prof-school', 'Bachelors', 'Masters', '11th', 'Assoc-voc','1st-4th', '5th-6th', 'Assoc-acdm', '12th', '9th', 'Preschool']

#df.sort_values("education.num") 
# De 1 - preschool a 16 - Doctorate

#df.race.unique() # 5 val

#df.sex.unique() # 2 val
#df.occupation.unique() # 14 val

#df.fnlwgt.unique().shape
#sns.distplot(df.fnlwgt)


#df['income']=df['income'].map({'<=50K': 0, '>50K': 1, '<=50K.': 0, '>50K.': 1})
#a_dummies = ["income"]
#columnas_dummies = ["income"]
#df_dummies = pd.get_dummies(df,a_dummies,columns=columnas_dummies)

# %% [markdown]
# Hacemos cambios en los datos.

# %%
df["sex"] = np.where(df.sex == "Male", 0,1) #dos valores
df.drop("education",1,inplace=True)
df["income"] = np.where(df.income == '<=50K', 0, 1) #dos valores, a una variable dummy 

df
# Out:
#        age         workclass  fnlwgt  education.num      marital.status  \
# 1       82           Private  132870              9             Widowed
# 3       54           Private  140359              4            Divorced
# 4       41           Private  264663             10           Separated
# 5       34           Private  216864              9            Divorced
# 6       38           Private  150601              6           Separated
# 7       74         State-gov   88638             16       Never-married
# 8       68       Federal-gov  422013              9            Divorced
# 10      45           Private  172274             16            Divorced
# 11      38  Self-emp-not-inc  164526             15       Never-married
# 12      52           Private  129177             13             Widowed
# 13      32           Private  136204             14           Separated
# 15      46           Private   45363             15            Divorced
# 16      45           Private  172822              7            Divorced
# 17      57           Private  317847             14            Divorced
# 19      34           Private  203034             13           Separated
# ...    ...               ...     ...            ...                 ...
# 32546   31           Private  199655             14            Divorced
# 32547   39         Local-gov  111499             12  Married-civ-spouse
# 32548   37           Private  198216             12            Divorced
# 32549   43           Private  260761              9  Married-civ-spouse
# 32550   43         State-gov  255835             10            Divorced
# 32551   43  Self-emp-not-inc   27242             10  Married-civ-spouse
# 32552   32           Private   34066              6  Married-civ-spouse
# 32553   43           Private   84661             11  Married-civ-spouse
# 32554   32           Private  116138             14       Never-married
# 32555   53           Private  321865             14  Married-civ-spouse
# 32556   22           Private  310152             10       Never-married
# 32557   27           Private  257302             12  Married-civ-spouse
# 32558   40           Private  154374              9  Married-civ-spouse
# 32559   58           Private  151910              9             Widowed
# 32560   22           Private  201490              9       Never-married
#
#               occupation    relationship                race  sex  \
# 1        Exec-managerial   Not-in-family               White    1
# 3      Machine-op-inspct       Unmarried               White    1
# 4         Prof-specialty       Own-child               White    1
# 5          Other-service       Unmarried               White    1
# 6           Adm-clerical       Unmarried               White    0
# 7         Prof-specialty  Other-relative               White    1
# 8         Prof-specialty   Not-in-family               White    1
# 10        Prof-specialty       Unmarried               Black    1
# 11        Prof-specialty   Not-in-family               White    0
# 12         Other-service   Not-in-family               White    1
# 13       Exec-managerial   Not-in-family               White    0
# 15        Prof-specialty   Not-in-family               White    0
# 16      Transport-moving   Not-in-family               White    0
# 17       Exec-managerial   Not-in-family               White    0
# 19                 Sales   Not-in-family               White    0
# ...                  ...             ...                 ...  ...
# 32546      Other-service   Not-in-family               Other    1
# 32547       Adm-clerical            Wife               White    1
# 32548       Tech-support   Not-in-family               White    1
# 32549  Machine-op-inspct         Husband               White    0
# 32550       Adm-clerical  Other-relative               White    1
# 32551       Craft-repair         Husband               White    0
# 32552  Handlers-cleaners         Husband  Amer-Indian-Eskimo    0
# 32553              Sales         Husband               White    0
# 32554       Tech-support   Not-in-family  Asian-Pac-Islander    0
# 32555    Exec-managerial         Husband               White    0
# 32556    Protective-serv   Not-in-family               White    0
# 32557       Tech-support            Wife               White    1
# 32558  Machine-op-inspct         Husband               White    0
# 32559       Adm-clerical       Unmarried               White    1
# 32560       Adm-clerical       Own-child               White    0
#
#        capital.gain  capital.loss  hours.per.week native.country  income
# 1                 0          4356              18  United-States       0
# 3                 0          3900              40  United-States       0
# 4                 0          3900              40  United-States       0
# 5                 0          3770              45  United-States       0
# 6                 0          3770              40  United-States       0
# 7                 0          3683              20  United-States       1
# 8                 0          3683              40  United-States       0
# 10                0          3004              35  United-States       1
# 11                0          2824              45  United-States       1
# 12                0          2824              20  United-States       1
# 13                0          2824              55  United-States       1
# 15                0          2824              40  United-States       1
# 16                0          2824              76  United-States       1
# 17                0          2824              50  United-States       1
# 19                0          2824              50  United-States       1
# ...             ...           ...             ...            ...     ...
# 32546             0             0              30  United-States       0
# 32547             0             0              20  United-States       1
# 32548             0             0              40  United-States       0
# 32549             0             0              40         Mexico       0
# 32550             0             0              40  United-States       0
# 32551             0             0              50  United-States       0
# 32552             0             0              40  United-States       0
# 32553             0             0              45  United-States       0
# 32554             0             0              11         Taiwan       0
# 32555             0             0              40  United-States       1
# 32556             0             0              40  United-States       0
# 32557             0             0              38  United-States       0
# 32558             0             0              40  United-States       1
# 32559             0             0              40  United-States       0
# 32560             0             0              20  United-States       0
#
# [30162 rows x 14 columns]

# %%
sns.heatmap(df.corr());
